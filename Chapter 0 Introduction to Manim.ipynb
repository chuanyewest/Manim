# %% [markdown]
# <a href="https://colab.research.google.com/github/chuanyewest/Manim/blob/main/Chapter%200%20Introduction%20to%20Manim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Manim: making math visible

# %% [markdown]
# # Lab: Introduction

# %% [markdown]
# Manim is a powerful engine to produce cool animations that illustrate mathematical concepts in a visualized way. This tutorial is aiming to help you get familiar with Manim quickly.
# To run this lab, you will need three things:
# * An installation of `Python3`, which is the specific version of `Python` used in this lab.
# * An installation of `ManimCE`, the community edit version of `Manim`.
# * Access to `Jupyter`, a popular python interface that runs code through a file called a notebook.

# %% [markdown]
# Installation details of `ManimCE` can be found in https://www.manim.community/.
#
# There are a number of ways to get access to `Jupyter`. Here are just a few:
# * Using Google’s `Colaboratory` service: colab.research.google.com/.
# * Using `JupyterHub`, available at jupyter.org/hub.
# * Using your own `jupyter` installation. Installation instructions are
# available at jupyter.org/install.
#
# Throughout the whole tutorial, we will mainly focus on using `Colaboratory` for demonstration purpose.

# %% [markdown]
# ## Download Manim in Google Colaboratory

# %% [markdown]
# To ensure Manim runs successfully each time, we need to install the specific numpy version  and **restart the runtime** afterward.

# %%
# !sudo apt update
# !sudo apt install -y build-essential libcairo2-dev libpango1.0-dev libffi-dev pkg-config texlive texlive-latex-extra texlive-fonts-extra texlive-latex-recommended texlive-science tipa ffmpeg
# !pip install manim==0.19.0 IPython==8.21.0 numpy==2.2.5
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 89 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# build-essential is already the newest version (12.9ubuntu3).
# libcairo2-dev is already the newest version (1.16.0-5ubuntu2).
# libffi-dev is already the newest version (3.4.2-4).
# pkg-config is already the newest version (0.29.2-1ubuntu3).
# texlive is already the newest version (2021.20220204-1).
# texlive-fonts-extra is already the newest version (2021.20220204-1).
# texlive-latex-extra is already the newest version (2021.20220204-1).
# texlive-latex-recommended is already the newest version (2021.20220204-1).
# texlive-science is already the newest version (2021.20220204-1).
# tipa is already the newest version (2:1.3-21).
# libpango1.0-dev is already the newest version (1.50.6+ds-2ubuntu1).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# The following packages were automatically installed and are no longer required:
#   libbz2-dev libpkgconf3 libreadline-dev
# Use 'sudo apt autoremove' to remove them.
# 0 upgraded, 0 newly installed, 0 to remove and 89 not upgraded.
# Collecting manim==0.19.0
#   Downloading manim-0.19.0-py3-none-any.whl.metadata (11 kB)
# Collecting IPython==8.21.0
#   Downloading ipython-8.21.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting numpy==2.2.5
#   Downloading numpy-2.2.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.11/dist-packages (from manim==0.19.0) (11.2.1)
# Requirement already satisfied: Pygments>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from manim==0.19.0) (2.19.1)
# Collecting av<14.0.0,>=9.0.0 (from manim==0.19.0)
#   Downloading av-13.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: beautifulsoup4>=4.12 in /usr/local/lib/python3.11/dist-packages (from manim==0.19.0) (4.13.4)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.11/dist-packages (from manim==0.19.0) (8.2.0)
# Collecting cloup>=2.0.0 (from manim==0.19.0)
#   Downloading cloup-3.0.7-py2.py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: decorator>=4.3.2 in /usr/local/lib/python3.11/dist-packages (from manim==0.19.0) (4.4.2)
# Collecting isosurfaces>=0.1.0 (from manim==0.19.0)
#   Downloading isosurfaces-0.1.2-py3-none-any.whl.metadata (3.3 kB)
# Collecting manimpango<1.0.0,>=0.5.0 (from manim==0.19.0)
#   Downloading manimpango-0.6.0.tar.gz (4.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 61.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting mapbox-earcut>=1.0.0 (from manim==0.19.0)
#   Downloading mapbox_earcut-1.0.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.2 kB)
# Collecting moderngl<6.0.0,>=5.0.0 (from manim==0.19.0)
#   Downloading moderngl-5.12.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.8 kB)
# Collecting moderngl-window>=2.0.0 (from manim==0.19.0)
#   Downloading moderngl_window-3.1.1-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: networkx>=2.6 in /usr/local/lib/python3.11/dist-packages (from manim==0.19.0) (3.4.2)
# Requirement already satisfied: pycairo<2.0.0,>=1.13 in /usr/local/lib/python3.11/dist-packages (from manim==0.19.0) (1.28.0)
# Collecting pydub>=0.20.0 (from manim==0.19.0)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: rich>=12.0.0 in /usr/local/lib/python3.11/dist-packages (from manim==0.19.0) (13.9.4)
# Requirement already satisfied: scipy>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from manim==0.19.0) (1.15.3)
# Collecting screeninfo>=0.7 (from manim==0.19.0)
#   Downloading screeninfo-0.8.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting skia-pathops>=0.7.0 (from manim==0.19.0)
#   Downloading skia_pathops-0.8.0.post2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.3 kB)
# Collecting srt>=3.0.0 (from manim==0.19.0)
#   Downloading srt-3.5.3.tar.gz (28 kB)
#   Preparing metadata (setup.py) ... done
# Collecting svgelements>=1.8.0 (from manim==0.19.0)
#   Downloading svgelements-1.9.6-py2.py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from manim==0.19.0) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from manim==0.19.0) (4.13.2)
# Collecting watchdog>=2.0.0 (from manim==0.19.0)
#   Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.9 MB/s eta 0:00:00
# Collecting jedi>=0.16 (from IPython==8.21.0)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from IPython==8.21.0) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /usr/local/lib/python3.11/dist-packages (from IPython==8.21.0) (3.0.51)
# Collecting stack-data (from IPython==8.21.0)
#   Downloading stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: traitlets>=5 in /usr/local/lib/python3.11/dist-packages (from IPython==8.21.0) (5.7.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from IPython==8.21.0) (4.9.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.12->manim==0.19.0) (2.7)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->IPython==8.21.0) (0.8.4)
# Collecting glcontext>=3.0.0 (from moderngl<6.0.0,>=5.0.0->manim==0.19.0)
#   Downloading glcontext-3.0.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.0 kB)
# Collecting pyglet>=2.0.0 (from moderngl-window>=2.0.0->manim==0.19.0)
#   Downloading pyglet-2.1.6-py3-none-any.whl.metadata (7.7 kB)
# Collecting pyglm<3,>=2.7.0 (from moderngl-window>=2.0.0->manim==0.19.0)
#   Downloading pyglm-2.8.2-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->IPython==8.21.0) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython==8.21.0) (0.2.13)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=12.0.0->manim==0.19.0) (3.0.0)
# Collecting executing>=1.2.0 (from stack-data->IPython==8.21.0)
#   Downloading executing-2.2.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting asttokens>=2.1.0 (from stack-data->IPython==8.21.0)
#   Downloading asttokens-3.0.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting pure-eval (from stack-data->IPython==8.21.0)
#   Downloading pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->manim==0.19.0) (0.1.2)
# Downloading manim-0.19.0-py3-none-any.whl (625 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 625.9/625.9 kB 37.6 MB/s eta 0:00:00
# Downloading ipython-8.21.0-py3-none-any.whl (810 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 810.0/810.0 kB 48.9 MB/s eta 0:00:00
# Downloading numpy-2.2.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 95.7 MB/s eta 0:00:00
# Downloading av-13.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.0/34.0 MB 27.5 MB/s eta 0:00:00
# Downloading cloup-3.0.7-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 kB 3.8 MB/s eta 0:00:00
# Downloading isosurfaces-0.1.2-py3-none-any.whl (11 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 61.0 MB/s eta 0:00:00
# Downloading mapbox_earcut-1.0.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.0/97.0 kB 8.6 MB/s eta 0:00:00
# Downloading moderngl-5.12.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (293 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.5/293.5 kB 20.7 MB/s eta 0:00:00
# Downloading moderngl_window-3.1.1-py3-none-any.whl (382 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 382.4/382.4 kB 25.4 MB/s eta 0:00:00
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading screeninfo-0.8.1-py3-none-any.whl (12 kB)
# Downloading skia_pathops-0.8.0.post2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 92.7 MB/s eta 0:00:00
# Downloading svgelements-1.9.6-py2.py3-none-any.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 12.2 MB/s eta 0:00:00
# Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 5.7 MB/s eta 0:00:00
# Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Downloading asttokens-3.0.0-py3-none-any.whl (26 kB)
# Downloading executing-2.2.0-py2.py3-none-any.whl (26 kB)
# Downloading glcontext-3.0.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.7/51.7 kB 3.9 MB/s eta 0:00:00
# Downloading pyglet-2.1.6-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 984.0/984.0 kB 54.4 MB/s eta 0:00:00
# Downloading pyglm-2.8.2-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (12.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 105.7 MB/s eta 0:00:00
# Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Building wheels for collected packages: manimpango, srt
#   Building wheel for manimpango (pyproject.toml) ... done
#   Created wheel for manimpango: filename=manimpango-0.6.0-cp311-cp311-linux_x86_64.whl size=446519 sha256=3d20dd1a71dcb5d2c473c6e24535205e383970cfd54acf8cd9fc10a7c26d8b16
#   Stored in directory: /root/.cache/pip/wheels/b5/f7/af/f4cc5b792eddb785bb8aa382eb9b5aab2af499debb70757ea8
#   Building wheel for srt (setup.py) ... done
#   Created wheel for srt: filename=srt-3.5.3-py3-none-any.whl size=22427 sha256=47bcf780a454931ac08c28f96b9f9452ff2a6d5230c50e7e23c96e3115aadae7
#   Stored in directory: /root/.cache/pip/wheels/1f/43/f1/23ee9119497fcb57d9f7046fbf34c6d9027c46a1fa7824cf08
# Successfully built manimpango srt
# Installing collected packages: svgelements, pyglm, pydub, pure-eval, glcontext, watchdog, srt, skia-pathops, screeninfo, pyglet, numpy, moderngl, manimpango, jedi, executing, cloup, av, asttokens, stack-data, moderngl-window, mapbox-earcut, isosurfaces, manim, IPython
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: IPython
#     Found existing installation: ipython 7.34.0
#     Uninstalling ipython-7.34.0:
#       Successfully uninstalled ipython-7.34.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipython==7.34.0, but you have ipython 8.21.0 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.2.5 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.5 which is incompatible.
# Successfully installed IPython-8.21.0 asttokens-3.0.0 av-13.1.0 cloup-3.0.7 executing-2.2.0 glcontext-3.0.0 isosurfaces-0.1.2 jedi-0.19.2 manim-0.19.0 manimpango-0.6.0 mapbox-earcut-1.0.3 moderngl-5.12.0 moderngl-window-3.1.1 numpy-2.2.5 pure-eval-0.2.3 pydub-0.25.1 pyglet-2.1.6 pyglm-2.8.2 screeninfo-0.8.1 skia-pathops-0.8.0.post2 srt-3.5.3 stack-data-0.6.3 svgelements-1.9.6 watchdog-6.0.0

# %% [markdown]
# After running the installation, restart the runtime and call the Manim.
#
# To test that whether you have make all the installations properly, run the code below.

# %%
from manim import *
config.media_width = "75%"
config.verbosity = "WARNING"

# %% [markdown]
# In `Colaboratory`, it won't output anything. However, in local environment, a successful output should be a message printing the installed version of the Manim library.

# %% [markdown]
# # Hello World!

# %% [markdown]
# We finally come to our openning ceremony. Run the code below.

# %%
# %%manim -qm HelloWorld
#
# class HelloWorld(Scene):
#     def construct(self):
#         text_1 = Text('Hello, Manim World!', font_size=80)
#         self.play(Write(text_1), run_time=4)
# Out:
# [02/10/25 15:57:50] INFO     Animation 0 : Using cached data (hash :                           ]8;id=633364;file://c:\Users\dengs\AppData\Local\Programs\Python\Python311\Lib\site-packages\manim\renderer\cairo_renderer.py\cairo_renderer.py]8;;\:]8;id=608797;file://c:\Users\dengs\AppData\Local\Programs\Python\Python311\Lib\site-packages\manim\renderer\cairo_renderer.py#78\78]8;;\
#                              274514146_370976453_223132457)
#                     INFO     Combining to Movie file.                                      ]8;id=751098;file://c:\Users\dengs\AppData\Local\Programs\Python\Python311\Lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=99559;file://c:\Users\dengs\AppData\Local\Programs\Python\Python311\Lib\site-packages\manim\scene\scene_file_writer.py#617\617]8;;\
#                     INFO                                                                   ]8;id=356035;file://c:\Users\dengs\AppData\Local\Programs\Python\Python311\Lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=722426;file://c:\Users\dengs\AppData\Local\Programs\Python\Python311\Lib\site-packages\manim\scene\scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              'C:\Users\dengs\Downloads\media\videos\Downloads\720p30\Hello
#                              World.mp4'
#                     INFO     Rendered HelloWorld                                                       ]8;id=816415;file://c:\Users\dengs\AppData\Local\Programs\Python\Python311\Lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=291835;file://c:\Users\dengs\AppData\Local\Programs\Python\Python311\Lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 1 animations
# <video src="media\jupyter\HelloWorld@2025-02-10@15-57-50.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# If you can see a video that produce the text 'Hello World!' in the middle, congradulations! You have created your first scene. Though simple, it contains some important information. We will go through it step by step. First,
# ```py
#     class HelloWorld(Scene):
#         def construct(self):
# ```
# Here we define a new Manim scene named `HelloWorld`, and define the `construct` method which acts as the scheme of the video. We describe what we want to render in the scene in the content of `construct`.
# ```py
# text_1 = Text('Hello, Manim World!', font_size=80)
# ```
# In Manim, we called those _Mathematical Objects that can be displayed on the screen_ as `Mobjects`. Here we create a `Text` Moject named `text_1`. It is worth mentioning that Manim provides powerful _text animation_ tools, which we will try more later. Here we set the font size of the text to be 80, which can be changed by your own preference.
# ```py
# self.play(Write(text_1), run_time=4)
# ```
# This is where we finally produce something on our scene. `self.play` is an important command in manim, as everytime we want to render something on the scene, we use `self.play` to do so. In this case, since we want produce a `Text` object on the scene, we use the `Write` method. The second argument `run_time` is the time duration of the animation. Choose this properly can make the pace of your video more comfortable to the audience.

# %% [markdown]
# Now, let us produce our first `2D graph` scene with the code below.

# %%
# %%manim -qm SquareToCircle
#
# class SquareToCircle(Scene):
#    def construct(self):
#       square = Square()
#       circle = Circle()
#       circle.set_fill(PINK, opacity=0.5)
#       self.play(Create(square))
#       self.wait() # which is same as self.wait(1)
#       self.play(Transform(square, circle))
#       self.wait()
# Out:
# [02/07/25 16:54:03] INFO     Animation 0 : Partial movie file written in                   ]8;id=90197;file://c:\Users\dengs\AppData\Local\Programs\Python\Python311\Lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=899459;file://c:\Users\dengs\AppData\Local\Programs\Python\Python311\Lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\dengs\Downloads\media\videos\Downloads\720p30\parti
#                              al_movie_files\SquareToCircle\274514146_476749358_223132457.m
#                              p4'
#                     INFO     Animation 1 : Partial movie file written in                   ]8;id=956594;file://c:\Users\dengs\AppData\Local\Programs\Python\Python311\Lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=271357;file://c:\Users\dengs\AppData\Local\Programs\Python\Python311\Lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\dengs\Downloads\media\videos\Downloads\720p30\parti
#                              al_movie_files\SquareToCircle\2789044632_3315967912_116916078
#                              8.mp4'
# [02/07/25 16:54:04] INFO     Animation 2 : Partial movie file written in                   ]8;id=705452;file://c:\Users\dengs\AppData\Local\Programs\Python\Python311\Lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=53300;file://c:\Users\dengs\AppData\Local\Programs\Python\Python311\Lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\dengs\Downloads\media\videos\Downloads\720p30\parti
#                              al_movie_files\SquareToCircle\207390714_787651769_3531628062.
#                              mp4'
#                     INFO     Animation 3 : Partial movie file written in                   ]8;id=21116;file://c:\Users\dengs\AppData\Local\Programs\Python\Python311\Lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=562555;file://c:\Users\dengs\AppData\Local\Programs\Python\Python311\Lib\site-packages\manim\scene\scene_file_writer.py#527\527]8;;\
#                              'C:\Users\dengs\Downloads\media\videos\Downloads\720p30\parti
#                              al_movie_files\SquareToCircle\207390714_3315967912_4134102349
#                              .mp4'
#                     INFO     Combining to Movie file.                                      ]8;id=508843;file://c:\Users\dengs\AppData\Local\Programs\Python\Python311\Lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=845957;file://c:\Users\dengs\AppData\Local\Programs\Python\Python311\Lib\site-packages\manim\scene\scene_file_writer.py#617\617]8;;\
#                     INFO                                                                   ]8;id=490958;file://c:\Users\dengs\AppData\Local\Programs\Python\Python311\Lib\site-packages\manim\scene\scene_file_writer.py\scene_file_writer.py]8;;\:]8;id=629799;file://c:\Users\dengs\AppData\Local\Programs\Python\Python311\Lib\site-packages\manim\scene\scene_file_writer.py#736\736]8;;\
#                              File ready at
#                              'C:\Users\dengs\Downloads\media\videos\Downloads\720p30\Squar
#                              eToCircle.mp4'
#                     INFO     Rendered SquareToCircle                                                   ]8;id=724891;file://c:\Users\dengs\AppData\Local\Programs\Python\Python311\Lib\site-packages\manim\scene\scene.py\scene.py]8;;\:]8;id=121397;file://c:\Users\dengs\AppData\Local\Programs\Python\Python311\Lib\site-packages\manim\scene\scene.py#241\241]8;;\
#                              Played 4 animations
# <video src="media\jupyter\SquareToCircle@2025-02-07@16-54-04.mp4" controls autoplay loop style="max-width: 60%;"  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# This time you have witnessed another important Manim technique, that is to transfrom one `Mobject` to another.
# ```py
#     square = Square()
#     circle = Circle()
#     circle.set_fill(PINK, opacity=0.5)
# ```
# In these two lines, we create two Mobjects, a `Square` Mobject(with default parameter) and a `Circle` Mobject where we initialize it with a fill `color` and `opacity`. Now we are going to add them into the scene.
# ```py
#     self.play(Create(square))
#     self.play(Transform(square, circle))
#     self.wait()
# ```
# Here we used the `Create` method, which draws the `Square` Mobject(not simply makes it appear) in the scene. There are several methods to create a Mobject in the scene, for instance, `FadeIn`, and `DrawBorderThenFill`, you can try them out.
# Then we used the `Transform` method to transform it into the `Circle` Mobject we created, then pause the animation for one second(by default) and finishes the animation.

# %% [markdown]
# What we can do with manim is far beyond that. Next, we will build our first `3D graph` scene.

# %%
# %%manim -qm Rotation3DExample
#
# class Rotation3DExample(ThreeDScene):
#     def construct(self):
#         cube = Cube(side_length=3, fill_opacity=1)
#
#         self.begin_ambient_camera_rotation(rate=0.3)
#
#         self.set_camera_orientation(phi= 45 * DEGREES, theta= 45 * DEGREES)
#         # phi is the vertical angle, and theta is the horizontal angle
#
#         self.play(Write(cube), run_time=2)
#
#         self.wait(3)
#
#         self.play(Unwrite(cube), run_time=2)
# Out:
# Manim Community v0.19.0
# <video controls autoplay loop style="max-width: 75%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# We create a `Cube` Mobject using the following code. This time, instead of using the default parameters, we set the `side_length` and `fill_capacity` for the `Cube` Mobject.
# ```py
#     cube = Cube(side_length=3, fill_opacity=1)
# ```
# It is always a good exercise to try out different combinations of parameters to see what happens, so we can get a better understanding of the Mobjects. Note that you can check the parameters for any specific `Mobject` by typing `?` before the name of the Mobject.

# %%
# ?Cube
# Out:
# Init signature:
# Cube(
#     side_length: 'float' = 2,
#     fill_opacity: 'float' = 0.75,
#     fill_color: 'Color' = '#58C4DD',
#     stroke_width: 'float' = 0,
#     **kwargs,
# ) -> 'None'
# Docstring:
# A three-dimensional cube.
#
# Parameters
# ----------
# side_length
#     Length of each side of the :class:`Cube`.
# fill_opacity
#     The opacity of the :class:`Cube`, from 0 being fully transparent to 1 being
#     fully opaque. Defaults to 0.75.
# fill_color
#     The color of the :class:`Cube`.
# stroke_width
#     The width of the stroke surrounding each face of the :class:`Cube`.
#
# Examples
# --------
#
# .. manim:: CubeExample
#     :save_last_frame:
#
#     class CubeExample(ThreeDScene):
#         def construct(self):
#             self.set_camera_orientation(phi=75*DEGREES, theta=-45*DEGREES)
#
#             axes = ThreeDAxes()
#             cube = Cube(side_length=3, fill_opacity=0.7, fill_color=BLUE)
#             self.add(cube)
# File:           c:\users\dengs\appdata\local\programs\python\python311\lib\site-packages\manim\mobject\three_d\three_dimensions.py
# Type:           ConvertToOpenGL
# Subclasses:     Prism

# %% [markdown]
# `Camera` plays an extremely important role in 3D animation. Just like we need our eyes to see the world, we need a camera in appropriate position and angle to observe the 3D scene.
# ```py
#     self.begin_ambient_camera_rotation(rate=0.3)
#     self.set_camera_orientation(phi= 45 * DEGREES, theta= 45 * DEGREES)
# ```
# The lines above are used to control the rotation speed and angles of the camera. The `phi` controls the vertical viewing angle, and the `theta` controls the horizontal viewing angle. You can try out different values of angle to see how you version change.

# %% [markdown]
# Up to now, you have already seen the three main types of animations you can create with Manim: `text animations`, `2D animations`, and `3D animations`. In the following tutorials, we will introduce them in more detail, starting from introducing basic Mobjects, to how to operate them using different methods, and how to create your own animations.
#
# Note that `Manim` is updating quickly, which means new commands will be invented while the old ones may be erased. Therefore, the ultimate goal for this tutorial series is not explaining every single command to you, but helping you building basic techniques of animation production, and you should be able to dig deeper according to your needs by reading through the official library.
